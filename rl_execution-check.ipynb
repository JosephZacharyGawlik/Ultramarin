# %% [markdown]
# # RL for Optimal Trade Execution
#
# A PPO agent that makes per-second execution decisions based on the current order book state.
# Instead of predicting 60 seconds ahead, the agent reacts to what it sees right now.

# %%
import os, sys, subprocess

# Colab setup
if os.path.exists("/content"):
    # Always ensure we're in the right directory
    repo_dir = "/content/Ultramarin"

    # Clone repo if needed (for simulate_walk_the_book.py)
    if not os.path.isdir(os.path.join(repo_dir, "utils")):
        subprocess.run(["git", "clone", "-q", "-b", "potentially-improve-model",
                        "https://github.com/JosephZacharyGawlik/Ultramarin.git"],
                       cwd="/content")

    os.chdir(repo_dir)
    if repo_dir not in sys.path:
        sys.path.insert(0, repo_dir)

    # Mount Drive and copy data if needed
    dst = os.path.join(repo_dir, "data")
    if not os.path.isdir(dst) or not any(
        d for d in os.listdir(dst) if os.path.isdir(os.path.join(dst, d))
    ):
        from google.colab import drive
        drive.mount('/content/drive')
        src = "/content/drive/MyDrive/data"
        os.makedirs(dst, exist_ok=True)
        subprocess.run(["cp", "-r", f"{src}/.", dst], capture_output=True, text=True)
        print("Data copied.")
    else:
        print(f"Data already present at {dst}")

subprocess.run([sys.executable, "-m", "pip", "install", "-q",
                "gymnasium", "stable-baselines3"], capture_output=True)
print("Setup complete.")
# Out:
# Data already present at /content/Ultramarin/data
# Setup complete.

# %%
import numpy as np
import pandas as pd
import math
import warnings
import random
from pathlib import Path

import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO

from data.simulate_walk_the_book import simulate_walk_the_book

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# === Change this to switch currencies ===
data_asset = "BTCUSDT"

KNOWN_VOLUMES = {
    "BTCUSDT": 4.0, "ETHUSDT": 55.0, "LTCUSDT": 51.0,
    "SOLUSDT": 315.0, "ADAUSDT": 10436.0, "DOGEUSDT": 60349.0, "XRPUSDT": 13736.0,
}
OPTIMAL_K = {
    "BTCUSDT": 14, "ETHUSDT": 26, "LTCUSDT": 16,
    "SOLUSDT": 17, "ADAUSDT": 7, "DOGEUSDT": 20, "XRPUSDT": 20,
}

volume_to_fill = KNOWN_VOLUMES[data_asset]
K_SECONDS = OPTIMAL_K[data_asset]

root = Path("data")
Y_path = root / data_asset / "y_train.parquet"

print(f"Currency: {data_asset}")
print(f"Volume to fill: {volume_to_fill}")
print(f"TWAP-K baseline: K={K_SECONDS}")

# %% [markdown]
# ## Data Loading
#
# Load Y data (the 60-second execution window), split into train/val using the same
# chrono split as mhf-final (sort IDs, 80/20 split), and pre-extract LOB arrays per instrument.

# %%
ASK_PRICE_COLS = [f'ask_price_{i}' for i in range(1, 6)]
ASK_VOL_COLS = [f'ask_vol_{i}' for i in range(1, 6)]
BID_PRICE_COLS = [f'bid_price_{i}' for i in range(1, 6)]
BID_VOL_COLS = [f'bid_vol_{i}' for i in range(1, 6)]

Y_raw = pd.read_parquet(Y_path).sort_values(["anonymized_id", "time_in_hour"])

# Clean prices and volumes the same way as mhf-final:
# 1. Forward-fill then backfill prices (handles NaN at start AND middle)
# 2. Zero-fill volumes
price_cols = ASK_PRICE_COLS + BID_PRICE_COLS
vol_cols = ASK_VOL_COLS + BID_VOL_COLS
Y_raw[price_cols] = Y_raw.groupby("anonymized_id")[price_cols].transform(
    lambda s: s.ffill().bfill()
)
Y_raw[vol_cols] = Y_raw[vol_cols].fillna(0.0)

# Get valid instrument IDs (exactly 60 rows)
id_counts = Y_raw.groupby("anonymized_id").size()
valid_ids = sorted(id_counts[id_counts == 60].index.tolist())

# Chrono split: same logic as train_val() — sort IDs, take last 20% as val
split_idx = int(len(valid_ids) * 0.8)
train_ids = valid_ids[:split_idx]
val_ids = valid_ids[split_idx:]

print(f"Valid instruments: {len(valid_ids)}")
print(f"Train: {len(train_ids)}, Val: {len(val_ids)}")


def extract_instruments(ids, df):
    """Pre-extract LOB arrays for each instrument."""
    instruments = []
    skipped = 0
    for aid in ids:
        df_inst = df[df["anonymized_id"] == aid].sort_values("time_in_hour")
        if len(df_inst) != 60:
            continue

        ask_prices = df_inst[ASK_PRICE_COLS].to_numpy(dtype=np.float64)
        bid_prices = df_inst[BID_PRICE_COLS].to_numpy(dtype=np.float64)
        ask_vols = df_inst[ASK_VOL_COLS].to_numpy(dtype=np.float64)
        bid_vols = df_inst[BID_VOL_COLS].to_numpy(dtype=np.float64)

        # Skip if level-1 prices are still NaN (entire column was NaN — no data at all)
        if np.isnan(ask_prices[:, 0]).any() or np.isnan(bid_prices[:, 0]).any():
            skipped += 1
            continue

        close_vals = df_inst["close"].dropna()
        if len(close_vals) == 0:
            skipped += 1
            continue

        instruments.append({
            "id": aid,
            "ask_prices": ask_prices,
            "ask_vols": ask_vols,
            "bid_prices": bid_prices,
            "bid_vols": bid_vols,
            "close": close_vals.iloc[-1],
        })
    if skipped > 0:
        print(f"  Skipped {skipped} instruments (all-NaN prices or missing close)")
    return instruments


train_instruments = extract_instruments(train_ids, Y_raw)
val_instruments = extract_instruments(val_ids, Y_raw)

print(f"Train instruments loaded: {len(train_instruments)}")
print(f"Val instruments loaded: {len(val_instruments)}")
# Out:
# Valid instruments: 389
# Train: 311, Val: 78
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Train instruments loaded: 311
# Val instruments loaded: 78
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Gymnasium Environment
#
# Each episode = one instrument's last K-second execution window (same window as TWAP-K and Oracle).
# State: 12 features (remaining vol/time, spread, depth, imbalance, momentum, etc.)
# Action: 6 discrete choices — multiples of the TWAP-K rate
#
# **Key design: agent only trades in the last K seconds.**
# This matches the Oracle's optimization window and TWAP-K's execution window.
# Executing earlier hurts BPS because prices drift from the close price.
#
# **Reward (differential mark-to-market vs TWAP-K):**
# At each step, compare agent's cost-to-complete vs TWAP-K's cost-to-complete.
# Reward = change in advantage. Positive reward = agent is doing better than TWAP-K.

# %%
class TradeExecutionEnv(gym.Env):
    """
    RL environment for optimal trade execution in the last K seconds.

    Instead of trading across all 60 seconds (where price drift hurts BPS),
    the agent only trades in the last K seconds — the same window as TWAP-K
    and the Oracle optimizer. This makes the comparison fair and reduces noise.

    Reward: Differential mark-to-market advantage over TWAP-K.
    Action space: 10 discrete actions from 0x to 3x TWAP-K rate.
    """

    REWARD_SCALE = 10000  # puts rewards in ~bps units

    def __init__(self, instruments, volume_to_fill, K_seconds):
        super().__init__()
        self.instruments = instruments
        self.volume_to_fill = volume_to_fill
        self.K = K_seconds
        self.start_second = 60 - K_seconds
        self.twap_rate = volume_to_fill / K_seconds

        self.action_space = spaces.Discrete(10)
        self.action_multipliers = np.array([
            0.0, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 2.0, 2.5, 3.0
        ])

        self.observation_space = spaces.Box(
            low=-10.0, high=10.0, shape=(12,), dtype=np.float32
        )

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        if options and "instrument_idx" in options:
            idx = options["instrument_idx"]
        else:
            idx = self.np_random.integers(len(self.instruments))
        self.inst = self.instruments[idx]

        self.t = 0
        self.volume_executed = 0.0
        self.value_executed = 0.0
        self.volume_allocated = 0.0
        self.remaining_carry = 0.0
        self.prev_advantage = 0.0

        self._precompute_twap()

        abs_t = self.start_second
        self.arrival_mid = (
            self.inst["ask_prices"][abs_t, 0] + self.inst["bid_prices"][abs_t, 0]
        ) / 2

        return self._get_obs(), {}

    def _precompute_twap(self):
        """Run TWAP-K through walk-the-book for the last K seconds."""
        self.twap_cost_per_step = np.zeros(self.K)
        self.twap_vol_per_step = np.zeros(self.K)
        carry = 0.0
        for step in range(self.K):
            abs_t = self.start_second + step
            to_fill = self.twap_rate + carry
            carry = 0.0
            filled = 0.0
            cost = 0.0
            remaining = to_fill
            for level in range(5):
                price = self.inst["ask_prices"][abs_t, level]
                avail = self.inst["ask_vols"][abs_t, level]
                if math.isnan(price) or math.isnan(avail):
                    continue
                take = min(remaining, avail)
                cost += take * price
                filled += take
                remaining -= take
                if remaining <= 1e-12:
                    break
            carry = remaining
            self.twap_cost_per_step[step] = cost
            self.twap_vol_per_step[step] = filled
        self.twap_cum_cost = np.cumsum(self.twap_cost_per_step)
        self.twap_cum_vol = np.cumsum(self.twap_vol_per_step)

    def _get_obs(self):
        if self.t >= self.K:
            return np.zeros(12, dtype=np.float32)

        abs_t = self.start_second + self.t
        ask_p = self.inst["ask_prices"][abs_t]
        ask_v = self.inst["ask_vols"][abs_t]
        bid_p = self.inst["bid_prices"][abs_t]
        bid_v = self.inst["bid_vols"][abs_t]
        mid = (ask_p[0] + bid_p[0]) / 2

        remaining_vol = max(0, self.volume_to_fill - self.volume_allocated)
        remaining_vol_frac = remaining_vol / (self.volume_to_fill + 1e-8)
        remaining_time_frac = (self.K - self.t) / self.K
        spread = (ask_p[0] - bid_p[0]) / (mid + 1e-8)
        mid_return = (mid - self.arrival_mid) / (self.arrival_mid + 1e-8)

        vol_imb_1 = (bid_v[0] - ask_v[0]) / (bid_v[0] + ask_v[0] + 1e-8)
        vol_imb_total = (bid_v.sum() - ask_v.sum()) / (bid_v.sum() + ask_v.sum() + 1e-8)
        ask_depth = ask_v.sum() / (self.volume_to_fill + 1e-8)
        bid_depth = bid_v.sum() / (self.volume_to_fill + 1e-8)

        cum_is = 0.0
        if self.volume_executed > 0:
            avg_price = self.value_executed / self.volume_executed
            cum_is = (avg_price - self.arrival_mid) / (self.arrival_mid + 1e-8)

        if abs_t >= 5:
            mid_prev = (self.inst["ask_prices"][abs_t-5, 0] + self.inst["bid_prices"][abs_t-5, 0]) / 2
            momentum = (mid - mid_prev) / (self.arrival_mid + 1e-8)
            prev_spread = (self.inst["ask_prices"][abs_t-5, 0] - self.inst["bid_prices"][abs_t-5, 0]) / (mid_prev + 1e-8)
            spread_change = spread - prev_spread
        else:
            momentum = 0.0
            spread_change = 0.0

        carry_frac = self.remaining_carry / (self.volume_to_fill + 1e-8)

        obs = np.array([
            remaining_vol_frac,
            remaining_time_frac,
            spread,
            mid_return,
            vol_imb_1,
            vol_imb_total,
            ask_depth,
            bid_depth,
            cum_is,
            momentum,
            spread_change,
            carry_frac,
        ], dtype=np.float32)

        obs = np.nan_to_num(obs, nan=0.0, posinf=10.0, neginf=-10.0)
        obs = np.clip(obs, -10.0, 10.0)
        return obs

    def step(self, action):
        position = self.action_multipliers[action] * self.twap_rate

        max_remaining = self.volume_to_fill - self.volume_allocated
        position = min(position, max(0.0, max_remaining))

        if self.t == self.K - 1:
            position = max(0.0, max_remaining)

        self.volume_allocated += position

        abs_t = self.start_second + self.t
        to_fill = position + self.remaining_carry
        self.remaining_carry = 0.0
        step_volume = 0.0
        step_cost = 0.0

        if to_fill > 1e-12:
            remaining = to_fill
            for level in range(5):
                price = self.inst["ask_prices"][abs_t, level]
                avail = self.inst["ask_vols"][abs_t, level]
                if math.isnan(price) or math.isnan(avail):
                    continue
                take = min(remaining, avail)
                step_cost += take * price
                step_volume += take
                remaining -= take
                if remaining <= 1e-12:
                    break
            self.remaining_carry = remaining

        self.volume_executed += step_volume
        self.value_executed += step_cost

        # === REWARD: Differential mark-to-market advantage over TWAP-K ===
        mid_t = (self.inst["ask_prices"][abs_t, 0] + self.inst["bid_prices"][abs_t, 0]) / 2
        if math.isnan(mid_t):
            mid_t = self.arrival_mid

        agent_remaining = self.volume_to_fill - self.volume_executed
        agent_total_cost = self.value_executed + agent_remaining * mid_t

        twap_remaining = self.volume_to_fill - self.twap_cum_vol[self.t]
        twap_total_cost = self.twap_cum_cost[self.t] + twap_remaining * mid_t

        normalizer = self.arrival_mid * self.volume_to_fill
        advantage = (twap_total_cost - agent_total_cost) / normalizer

        reward = (advantage - self.prev_advantage) * self.REWARD_SCALE
        self.prev_advantage = advantage

        reward = max(-100.0, min(100.0, reward))

        self.t += 1
        done = self.t >= self.K
        info = {}

        if done:
            fill_ratio = self.volume_executed / (self.volume_to_fill + 1e-8)
            if fill_ratio < 0.99:
                reward -= (1.0 - fill_ratio) * 100.0

            if self.volume_executed > 0:
                avg_price = self.value_executed / self.volume_executed
                close = self.inst["close"]
                bps = abs(avg_price - close) / close * 10000
                vol_penalty = min(100.0, self.volume_to_fill / self.volume_executed)
                info["bps"] = bps * vol_penalty
                info["fill_ratio"] = fill_ratio
            else:
                info["bps"] = 10000.0
                info["fill_ratio"] = 0.0

        obs = self._get_obs()
        return obs, reward, done, False, info


# === Sanity checks ===
test_env = TradeExecutionEnv(train_instruments, volume_to_fill, K_SECONDS)

obs, _ = test_env.reset()
twap_reward = 0
for _ in range(K_SECONDS):
    obs, reward, done, _, info = test_env.step(4)  # action 4 = 1.0x
    twap_reward += reward
    if done:
        break
print(f"TWAP policy (action=4, 1.0x): BPS={info.get('bps', 'N/A'):.4f}, "
      f"Fill={info.get('fill_ratio', 0):.2%}, Reward={twap_reward:.4f}")

obs, _ = test_env.reset()
skip_reward = 0
for _ in range(K_SECONDS):
    obs, reward, done, _, info = test_env.step(0)  # action 0 = 0.0x
    skip_reward += reward
    if done:
        break
print(f"Skip policy (action=0, 0.0x):  BPS={info.get('bps', 'N/A'):.4f}, "
      f"Fill={info.get('fill_ratio', 0):.2%}, Reward={skip_reward:.4f}")

obs, _ = test_env.reset()
fast_reward = 0
for _ in range(K_SECONDS):
    obs, reward, done, _, info = test_env.step(9)  # action 9 = 3.0x
    fast_reward += reward
    if done:
        break
print(f"Fast policy (action=9, 3.0x):  BPS={info.get('bps', 'N/A'):.4f}, "
      f"Fill={info.get('fill_ratio', 0):.2%}, Reward={fast_reward:.4f}")

obs, _ = test_env.reset()
rand_reward = 0
for _ in range(K_SECONDS):
    obs, reward, done, _, info = test_env.step(test_env.action_space.sample())
    rand_reward += reward
    if done:
        break
print(f"Random policy:                 BPS={info.get('bps', 'N/A'):.4f}, "
      f"Fill={info.get('fill_ratio', 0):.2%}, Reward={rand_reward:.4f}")

nan_count = 0
for _ in range(20):
    obs, _ = test_env.reset()
    for _ in range(K_SECONDS):
        if np.isnan(obs).any():
            nan_count += 1
        obs, _, done, _, _ = test_env.step(test_env.action_space.sample())
        if done:
            break
print(f"\nNaN check: {nan_count} NaN observations in 20 episodes (should be 0)")
print(f"Episode length: {K_SECONDS} steps | Actions: {len(test_env.action_multipliers)} "
      f"({', '.join(f'{m}x' for m in test_env.action_multipliers)})")
# Out:
# TWAP policy (action=4, 1.0x): BPS=8.6460, Fill=100.00%, Reward=0.0000
# Skip policy (action=0, 0.0x):  BPS=6.2792, Fill=100.00%, Reward=-4.3734
# Fast policy (action=9, 3.0x):  BPS=12.9966, Fill=100.00%, Reward=-4.3402
# Random policy:                 BPS=1.4236, Fill=100.00%, Reward=0.4825
#
# NaN check: 0 NaN observations in 20 episodes (should be 0)
# Episode length: 16 steps | Actions: 10 (0.0x, 0.25x, 0.5x, 0.75x, 1.0x, 1.25x, 1.5x, 2.0x, 2.5x, 3.0x)

# %% [markdown]
# ## Training
#
# PPO (Proximal Policy Optimization) with a small MLP policy (2 hidden layers, 64 neurons each).
# PPO uses trajectory rollouts rather than replay buffers, making it better suited for
# environments with small per-step reward signals. RL-Exec (BTC-USD execution) used PPO
# for this exact reason.

# %%
train_env = TradeExecutionEnv(train_instruments, volume_to_fill, K_SECONDS)

# Linear LR decay: 3e-4 → 0 over training
def linear_schedule(progress_remaining: float) -> float:
    return progress_remaining * 3e-4

model = PPO(
    "MlpPolicy",
    train_env,
    learning_rate=linear_schedule,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.01,
    vf_coef=0.5,
    max_grad_norm=0.5,
    policy_kwargs={"net_arch": [64, 64]},
    verbose=1,
    seed=SEED,
)

TOTAL_TIMESTEPS = 1_000_000
print(f"Training for {TOTAL_TIMESTEPS} timesteps (~{TOTAL_TIMESTEPS // K_SECONDS} episodes)...")
print(f"LR schedule: 3e-4 → 0 (linear decay)")
model.learn(total_timesteps=TOTAL_TIMESTEPS)
print("Training complete.")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Training for 1000000 timesteps (~62500 episodes)...
# LR schedule: 3e-4 → 0 (linear decay)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16       |
# |    ep_rew_mean     | 0.27     |
# | time/              |          |
# |    fps             | 468      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 0.119        |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0117259305 |
# |    clip_fraction        | 0.0685       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | -0.0239      |
# |    learning_rate        | 0.000299     |
# |    loss                 | 0.92         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00765     |
# |    value_loss           | 3            |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.287      |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009647699 |
# |    clip_fraction        | 0.0857      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.0404      |
# |    learning_rate        | 0.000299    |
# |    loss                 | 1.11        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 2.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.203      |
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011075065 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.0814      |
# |    learning_rate        | 0.000298    |
# |    loss                 | 1.86        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00802    |
# |    value_loss           | 3.33        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 0.233        |
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 5            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0074947663 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.26        |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.000298     |
# |    loss                 | 6.22         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00532     |
# |    value_loss           | 5.63         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.297      |
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 6           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008362593 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.0852      |
# |    learning_rate        | 0.000297    |
# |    loss                 | 1.14        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 4.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.657      |
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 7           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009551959 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.000296    |
# |    loss                 | 4.42        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 10          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.641      |
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 8           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009833239 |
# |    clip_fraction        | 0.0913      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.000296    |
# |    loss                 | 3.17        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 7.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.559      |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 9           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010188432 |
# |    clip_fraction        | 0.0731      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.117       |
# |    learning_rate        | 0.000295    |
# |    loss                 | 21.3        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00811    |
# |    value_loss           | 10.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.363      |
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 10          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010876097 |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.000294    |
# |    loss                 | 4.66        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00994    |
# |    value_loss           | 6.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.203       |
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 11          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009721935 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 0.124       |
# |    learning_rate        | 0.000294    |
# |    loss                 | 1.13        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00791    |
# |    value_loss           | 4.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.0574     |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 12          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010690945 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.0729      |
# |    learning_rate        | 0.000293    |
# |    loss                 | 1.19        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00826    |
# |    value_loss           | 3.45        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.149       |
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 13          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008610178 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.000293    |
# |    loss                 | 1.14        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00987    |
# |    value_loss           | 3.79        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16         |
# |    ep_rew_mean          | -0.266     |
# | time/                   |            |
# |    fps                  | 418        |
# |    iterations           | 14         |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.00978801 |
# |    clip_fraction        | 0.0917     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.18      |
# |    explained_variance   | 0.136      |
# |    learning_rate        | 0.000292   |
# |    loss                 | 1.68       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00781   |
# |    value_loss           | 3.26       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.273      |
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 15          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010139175 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.000291    |
# |    loss                 | 3.03        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00916    |
# |    value_loss           | 3.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.0317      |
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 16          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010370875 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.000291    |
# |    loss                 | 1.85        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00896    |
# |    value_loss           | 4.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.132       |
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 17          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008716939 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.00029     |
# |    loss                 | 1.21        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00859    |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.634      |
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 18          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007629703 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.00029     |
# |    loss                 | 1.86        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00643    |
# |    value_loss           | 2.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.0772     |
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 19          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009690951 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 0.000289    |
# |    loss                 | 1.47        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00993    |
# |    value_loss           | 3.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.14       |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 20          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008236015 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.000288    |
# |    loss                 | 1.69        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00938    |
# |    value_loss           | 3.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.489      |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 21          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008209845 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.000288    |
# |    loss                 | 4.63        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 8.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.0557      |
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 22          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008382044 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.193       |
# |    learning_rate        | 0.000287    |
# |    loss                 | 3.36        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00951    |
# |    value_loss           | 4.62        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | -0.0837      |
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 23           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0075883763 |
# |    clip_fraction        | 0.0624       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.000286     |
# |    loss                 | 4.52         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00624     |
# |    value_loss           | 6.5          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.0177      |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 24          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012184788 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.0945      |
# |    learning_rate        | 0.000286    |
# |    loss                 | 1.34        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 3.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.43        |
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 25          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009393328 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.000285    |
# |    loss                 | 1.02        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 3           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.589      |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 26          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009275503 |
# |    clip_fraction        | 0.0913      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.000285    |
# |    loss                 | 0.677       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0099     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.0567     |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 27          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008965047 |
# |    clip_fraction        | 0.0725      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.000284    |
# |    loss                 | 0.823       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00891    |
# |    value_loss           | 5.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.0523     |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 28          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012418607 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.000283    |
# |    loss                 | 0.835       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.122      |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 29          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008174704 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.000283    |
# |    loss                 | 1.1         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00719    |
# |    value_loss           | 2.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.0162     |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 30          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008283335 |
# |    clip_fraction        | 0.0718      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.000282    |
# |    loss                 | 1.96        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00934    |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.0714     |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 31          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011299321 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.18        |
# |    learning_rate        | 0.000282    |
# |    loss                 | 2.5         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 3.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.105       |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 32          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007910685 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.000281    |
# |    loss                 | 1.31        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00919    |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.0716     |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 33          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008395493 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.0881      |
# |    learning_rate        | 0.00028     |
# |    loss                 | 3.5         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00904    |
# |    value_loss           | 3.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.421       |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 34          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009511111 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.00028     |
# |    loss                 | 1.5         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00891    |
# |    value_loss           | 2.31        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 0.0378       |
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 35           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0096148625 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.1         |
# |    explained_variance   | 0.0809       |
# |    learning_rate        | 0.000279     |
# |    loss                 | 0.868        |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 3.15         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16         |
# |    ep_rew_mean          | 0.155      |
# | time/                   |            |
# |    fps                  | 415        |
# |    iterations           | 36         |
# |    time_elapsed         | 177        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01163664 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.07      |
# |    explained_variance   | 0.179      |
# |    learning_rate        | 0.000278   |
# |    loss                 | 0.896      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0128    |
# |    value_loss           | 2.34       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.285       |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 37          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009803878 |
# |    clip_fraction        | 0.0998      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.000278    |
# |    loss                 | 4.2         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 38          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008642954 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.000277    |
# |    loss                 | 1.69        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 3.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.225      |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 39          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008075621 |
# |    clip_fraction        | 0.0678      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 0.000277    |
# |    loss                 | 1.14        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00934    |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.423      |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 40          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009507667 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.000276    |
# |    loss                 | 0.728       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0099     |
# |    value_loss           | 3.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.203      |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 41          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.006948717 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.000275    |
# |    loss                 | 6.02        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0071     |
# |    value_loss           | 8.91        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.222       |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 42          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008084731 |
# |    clip_fraction        | 0.0725      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.000275    |
# |    loss                 | 2.32        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00891    |
# |    value_loss           | 3.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.159      |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 43          |
# |    time_elapsed         | 212         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007850647 |
# |    clip_fraction        | 0.0594      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.193       |
# |    learning_rate        | 0.000274    |
# |    loss                 | 0.957       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00702    |
# |    value_loss           | 2.19        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16         |
# |    ep_rew_mean          | -0.173     |
# | time/                   |            |
# |    fps                  | 415        |
# |    iterations           | 44         |
# |    time_elapsed         | 216        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01146552 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.99      |
# |    explained_variance   | 0.138      |
# |    learning_rate        | 0.000274   |
# |    loss                 | 1.58       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0142    |
# |    value_loss           | 2.72       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16         |
# |    ep_rew_mean          | 0.289      |
# | time/                   |            |
# |    fps                  | 414        |
# |    iterations           | 45         |
# |    time_elapsed         | 222        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00861704 |
# |    clip_fraction        | 0.0953     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.96      |
# |    explained_variance   | 0.17       |
# |    learning_rate        | 0.000273   |
# |    loss                 | 1.25       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0118    |
# |    value_loss           | 2.56       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.191      |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 46          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008624908 |
# |    clip_fraction        | 0.0739      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.000272    |
# |    loss                 | 2.93        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00929    |
# |    value_loss           | 3.76        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 0.288        |
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 47           |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0076329513 |
# |    clip_fraction        | 0.0803       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.225        |
# |    learning_rate        | 0.000272     |
# |    loss                 | 0.617        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 3.27         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.159      |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 48          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006609206 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.000271    |
# |    loss                 | 1.45        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00664    |
# |    value_loss           | 3.61        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 0.238        |
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 49           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0099581815 |
# |    clip_fraction        | 0.0719       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.153        |
# |    learning_rate        | 0.000271     |
# |    loss                 | 1.13         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00959     |
# |    value_loss           | 3            |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.242       |
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 50          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.009270598 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.00027     |
# |    loss                 | 0.781       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00898    |
# |    value_loss           | 2.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.0843      |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 51          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.007208531 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.000269    |
# |    loss                 | 0.968       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00647    |
# |    value_loss           | 6.05        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | -0.21        |
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 52           |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0093661025 |
# |    clip_fraction        | 0.0807       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.86        |
# |    explained_variance   | 0.171        |
# |    learning_rate        | 0.000269     |
# |    loss                 | 0.847        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00865     |
# |    value_loss           | 1.94         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | -0.586      |
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 53          |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.009219233 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.000268    |
# |    loss                 | 3.45        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00728    |
# |    value_loss           | 5.85        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | -0.121       |
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 54           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0077979923 |
# |    clip_fraction        | 0.0631       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.86        |
# |    explained_variance   | 0.156        |
# |    learning_rate        | 0.000267     |
# |    loss                 | 1.42         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00875     |
# |    value_loss           | 3.66         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.245       |
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 55          |
# ...
# |    clip_fraction        | 0.000537     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.115        |
# |    learning_rate        | 1.06e-05     |
# |    loss                 | 1.07         |
# |    n_updates            | 4710         |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 2.74         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 0.498        |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 473          |
# |    time_elapsed         | 2871         |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0019771613 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.316        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 5.95         |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 6.04         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 0.666        |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 474          |
# |    time_elapsed         | 2884         |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0013562903 |
# |    clip_fraction        | 0.0022       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 9.39e-06     |
# |    loss                 | 0.59         |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 2.71         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16            |
# |    ep_rew_mean          | 1.05          |
# | time/                   |               |
# |    fps                  | 335           |
# |    iterations           | 475           |
# |    time_elapsed         | 2896          |
# |    total_timesteps      | 972800        |
# | train/                  |               |
# |    approx_kl            | 0.00042671093 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | 0.192         |
# |    learning_rate        | 8.77e-06      |
# |    loss                 | 0.886         |
# |    n_updates            | 4740          |
# |    policy_gradient_loss | -0.000797     |
# |    value_loss           | 2.71          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 0.921        |
# | time/                   |              |
# |    fps                  | 335          |
# |    iterations           | 476          |
# |    time_elapsed         | 2909         |
# |    total_timesteps      | 974848       |
# | train/                  |              |
# |    approx_kl            | 0.0009031631 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.173        |
# |    learning_rate        | 8.16e-06     |
# |    loss                 | 1.79         |
# |    n_updates            | 4750         |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 3.03         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16          |
# |    ep_rew_mean          | 0.629       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 477         |
# |    time_elapsed         | 2922        |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 8.86957e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 7.55e-06    |
# |    loss                 | 1.81        |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.000542   |
# |    value_loss           | 8.96        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16            |
# |    ep_rew_mean          | 0.942         |
# | time/                   |               |
# |    fps                  | 333           |
# |    iterations           | 478           |
# |    time_elapsed         | 2934          |
# |    total_timesteps      | 978944        |
# | train/                  |               |
# |    approx_kl            | 0.00012921993 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.43         |
# |    explained_variance   | 0.36          |
# |    learning_rate        | 6.93e-06      |
# |    loss                 | 10.4          |
# |    n_updates            | 4770          |
# |    policy_gradient_loss | -0.000484     |
# |    value_loss           | 7.04          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 0.435        |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 479          |
# |    time_elapsed         | 2946         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0029435507 |
# |    clip_fraction        | 0.00527      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 6.32e-06     |
# |    loss                 | 2.29         |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.00287     |
# |    value_loss           | 4.02         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 0.807        |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 480          |
# |    time_elapsed         | 2958         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0010479321 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 5.7e-06      |
# |    loss                 | 1.58         |
# |    n_updates            | 4790         |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 3.38         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 1.01         |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 481          |
# |    time_elapsed         | 2970         |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0010872828 |
# |    clip_fraction        | 0.000684     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 5.09e-06     |
# |    loss                 | 1.69         |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 3.6          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16            |
# |    ep_rew_mean          | 0.804         |
# | time/                   |               |
# |    fps                  | 330           |
# |    iterations           | 482           |
# |    time_elapsed         | 2983          |
# |    total_timesteps      | 987136        |
# | train/                  |               |
# |    approx_kl            | 0.00042282222 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.45         |
# |    explained_variance   | 0.129         |
# |    learning_rate        | 4.47e-06      |
# |    loss                 | 1.65          |
# |    n_updates            | 4810          |
# |    policy_gradient_loss | -0.000408     |
# |    value_loss           | 3.15          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16            |
# |    ep_rew_mean          | 1.28          |
# | time/                   |               |
# |    fps                  | 330           |
# |    iterations           | 483           |
# |    time_elapsed         | 2996          |
# |    total_timesteps      | 989184        |
# | train/                  |               |
# |    approx_kl            | 1.8313323e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.46         |
# |    explained_variance   | 0.36          |
# |    learning_rate        | 3.86e-06      |
# |    loss                 | 2.5           |
# |    n_updates            | 4820          |
# |    policy_gradient_loss | -0.000212     |
# |    value_loss           | 8.83          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16            |
# |    ep_rew_mean          | 0.395         |
# | time/                   |               |
# |    fps                  | 329           |
# |    iterations           | 484           |
# |    time_elapsed         | 3007          |
# |    total_timesteps      | 991232        |
# | train/                  |               |
# |    approx_kl            | 0.00021615581 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | 0.299         |
# |    learning_rate        | 3.24e-06      |
# |    loss                 | 2.12          |
# |    n_updates            | 4830          |
# |    policy_gradient_loss | -0.000436     |
# |    value_loss           | 7.55          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16            |
# |    ep_rew_mean          | 0.369         |
# | time/                   |               |
# |    fps                  | 328           |
# |    iterations           | 485           |
# |    time_elapsed         | 3020          |
# |    total_timesteps      | 993280        |
# | train/                  |               |
# |    approx_kl            | 0.00014799446 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | 0.164         |
# |    learning_rate        | 2.63e-06      |
# |    loss                 | 1.5           |
# |    n_updates            | 4840          |
# |    policy_gradient_loss | -0.000726     |
# |    value_loss           | 2.88          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16            |
# |    ep_rew_mean          | 1.19          |
# | time/                   |               |
# |    fps                  | 328           |
# |    iterations           | 486           |
# |    time_elapsed         | 3031          |
# |    total_timesteps      | 995328        |
# | train/                  |               |
# |    approx_kl            | 4.6264904e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | 0.286         |
# |    learning_rate        | 2.02e-06      |
# |    loss                 | 1.44          |
# |    n_updates            | 4850          |
# |    policy_gradient_loss | -0.000355     |
# |    value_loss           | 6.72          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16            |
# |    ep_rew_mean          | 0.689         |
# | time/                   |               |
# |    fps                  | 327           |
# |    iterations           | 487           |
# |    time_elapsed         | 3044          |
# |    total_timesteps      | 997376        |
# | train/                  |               |
# |    approx_kl            | 3.0414842e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.44         |
# |    explained_variance   | 0.189         |
# |    learning_rate        | 1.4e-06       |
# |    loss                 | 2.26          |
# |    n_updates            | 4860          |
# |    policy_gradient_loss | -0.000187     |
# |    value_loss           | 4.22          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 0.342        |
# | time/                   |              |
# |    fps                  | 326          |
# |    iterations           | 488          |
# |    time_elapsed         | 3057         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 6.205228e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0.0646       |
# |    learning_rate        | 7.87e-07     |
# |    loss                 | 1.8          |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.000368    |
# |    value_loss           | 3.47         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16            |
# |    ep_rew_mean          | 0.554         |
# | time/                   |               |
# |    fps                  | 326           |
# |    iterations           | 489           |
# |    time_elapsed         | 3069          |
# |    total_timesteps      | 1001472       |
# | train/                  |               |
# |    approx_kl            | 1.4196848e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | 0.0889        |
# |    learning_rate        | 1.73e-07      |
# |    loss                 | 3.12          |
# |    n_updates            | 4880          |
# |    policy_gradient_loss | -2.41e-05     |
# |    value_loss           | 3.09          |
# -------------------------------------------
# Training complete.

# %% [markdown]
# ## Evaluation
#
# Run the trained agent on validation instruments and compare BPS against TWAP-K.
# Uses `simulate_walk_the_book()` for final BPS — same function as all other strategies.

# %%
def evaluate(model, instruments, volume_to_fill, K_seconds):
    """Evaluate RL agent vs multiple TWAP baselines on a set of instruments."""
    env = TradeExecutionEnv(instruments, volume_to_fill, K_seconds)
    rl_bps_list = []
    twap_k_bps_list = []
    twap_14_bps_list = []
    twap_60_bps_list = []
    rl_positions_all = []

    for i in range(len(instruments)):
        inst = instruments[i]
        ask_prices = inst["ask_prices"]
        ask_vols = inst["ask_vols"]
        bid_prices = inst["bid_prices"]
        bid_vols = inst["bid_vols"]
        close_price = inst["close"]

        # --- RL Agent ---
        obs, _ = env.reset(options={"instrument_idx": i})
        rl_positions = np.zeros(60)
        for step in range(K_seconds):
            action, _ = model.predict(obs, deterministic=True)

            position = env.action_multipliers[int(action)] * env.twap_rate
            max_remaining = volume_to_fill - env.volume_allocated
            position = min(position, max(0.0, max_remaining))
            if step == K_seconds - 1:
                position = max(0.0, max_remaining)

            abs_t = env.start_second + step
            rl_positions[abs_t] = position

            obs, _, done, _, _ = env.step(int(action))
            if done:
                break

        rl_positions_all.append(rl_positions)

        def compute_bps(positions):
            vol, avg = simulate_walk_the_book(
                positions, ask_prices, ask_vols, bid_prices, bid_vols
            )
            if vol > 0 and not np.isnan(avg):
                ie = abs(avg - close_price) / close_price * 10000
                vp = min(100.0, volume_to_fill / vol)
                return ie * vp
            return None

        # --- RL BPS ---
        bps = compute_bps(rl_positions)
        if bps is not None:
            rl_bps_list.append(bps)

        # --- TWAP-K ---
        twap_k_pos = np.zeros(60)
        twap_k_pos[-K_seconds:] = volume_to_fill / K_seconds
        bps = compute_bps(twap_k_pos)
        if bps is not None:
            twap_k_bps_list.append(bps)

        # --- TWAP-14 ---
        twap_14_pos = np.zeros(60)
        twap_14_pos[-14:] = volume_to_fill / 14
        bps = compute_bps(twap_14_pos)
        if bps is not None:
            twap_14_bps_list.append(bps)

        # --- TWAP-60 ---
        twap_60_pos = np.full(60, volume_to_fill / 60)
        bps = compute_bps(twap_60_pos)
        if bps is not None:
            twap_60_bps_list.append(bps)

    return (np.array(rl_bps_list), np.array(twap_k_bps_list),
            np.array(twap_14_bps_list), np.array(twap_60_bps_list),
            rl_positions_all)


rl_bps, twap_k_bps, twap_14_bps, twap_60_bps, rl_positions_all = evaluate(
    model, val_instruments, volume_to_fill, K_SECONDS
)

print(f"\n{'='*60}")
print(f"RESULTS: {data_asset} (volume={volume_to_fill})")
print(f"{'='*60}")
print(f"{'Strategy':<20} {'Mean BPS':>10} {'Median BPS':>12}")
print(f"{'-'*60}")
print(f"{'RL Agent':<20} {rl_bps.mean():>10.4f} {np.median(rl_bps):>12.4f}")
print(f"{'TWAP-' + str(K_SECONDS) + 's':<20} {twap_k_bps.mean():>10.4f} {np.median(twap_k_bps):>12.4f}")
print(f"{'TWAP-14s':<20} {twap_14_bps.mean():>10.4f} {np.median(twap_14_bps):>12.4f}")
print(f"{'TWAP-60s':<20} {twap_60_bps.mean():>10.4f} {np.median(twap_60_bps):>12.4f}")
print(f"{'-'*60}")

# Compare RL against each baseline
for name, baseline in [("TWAP-" + str(K_SECONDS), twap_k_bps),
                        ("TWAP-14", twap_14_bps),
                        ("TWAP-60", twap_60_bps)]:
    diff = baseline.mean() - rl_bps.mean()
    wins = (rl_bps < baseline).sum()
    pct = (rl_bps < baseline).mean() * 100
    label = "RL wins" if diff > 0 else "TWAP wins"
    print(f"RL vs {name:<8}: {diff:+.4f} bps ({label}), "
          f"RL wins {wins}/{len(rl_bps)} ({pct:.1f}%)")

print(f"{'='*60}")
print(f"Instruments evaluated: {len(rl_bps)}")
print(f"\nSubmission comparison (TWAP-14): 5.0781 BPS")
# Out:
# ============================================================
# RESULTS: LTCUSDT (volume=51.0)
# ============================================================
# Strategy               Mean BPS   Median BPS
# ------------------------------------------------------------
# RL Agent                 4.2573       3.1334
# TWAP-16s                 4.7656       3.7779
# TWAP-14s                 4.8387       3.9524
# TWAP-60s                 6.4251       5.8964
# ------------------------------------------------------------
# RL vs TWAP-16 : +0.5083 bps (RL wins), RL wins 45/78 (57.7%)
# RL vs TWAP-14 : +0.5814 bps (RL wins), RL wins 42/78 (53.8%)
# RL vs TWAP-60 : +2.1678 bps (RL wins), RL wins 58/78 (74.4%)
# ============================================================
# Instruments evaluated: 78
#
# Submission comparison (TWAP-14): 5.0781 BPS

# %% [markdown]
# ## Policy Analysis
#
# Examine what the agent learned: average position profile across instruments,
# compared to TWAP allocation.

# %%
# Average position profile
positions_array = np.array(rl_positions_all)  # [num_instruments, 60]
avg_positions = positions_array.mean(axis=0)

# TWAP-K profile for comparison
twap_profile = np.zeros(60)
twap_profile[-K_SECONDS:] = volume_to_fill / K_SECONDS

print("RL Agent — Average position profile (last K seconds):")
print(f"  Volume in last {K_SECONDS}s:   {avg_positions[-K_SECONDS:].sum():.4f} ({avg_positions[-K_SECONDS:].sum()/volume_to_fill*100:.1f}%)")
print(f"  Volume in last 5s:    {avg_positions[-5:].sum():.4f} ({avg_positions[-5:].sum()/volume_to_fill*100:.1f}%)")
print(f"  Volume at last sec:   {avg_positions[59]:.4f} ({avg_positions[59]/volume_to_fill*100:.1f}%)")
print()
print(f"Per-second breakdown (last {K_SECONDS} seconds):")
start = 60 - K_SECONDS
for s in range(start, 60):
    rl_avg = avg_positions[s]
    twap_avg = twap_profile[s]
    bar = '#' * int(rl_avg / volume_to_fill * 100)
    print(f"  t={s:2d}: RL={rl_avg:7.2f} TWAP={twap_avg:7.2f}  {bar}")
print()
print(f"Top 5 seconds by average position:")
top5 = np.argsort(avg_positions)[-5:][::-1]
for s in top5:
    print(f"  Second {s}: {avg_positions[s]:.4f} ({avg_positions[s]/volume_to_fill*100:.1f}%)")
# Out:
# RL Agent — Average position profile (last K seconds):
#   Volume in last 16s:   51.0000 (100.0%)
#   Volume in last 5s:    6.7224 (13.2%)
#   Volume at last sec:   0.5823 (1.1%)
#
# Per-second breakdown (last 16 seconds):
#   t=44: RL=   4.65 TWAP=   3.19  #########
#   t=45: RL=   4.79 TWAP=   3.19  #########
#   t=46: RL=   4.14 TWAP=   3.19  ########
#   t=47: RL=   3.90 TWAP=   3.19  #######
#   t=48: RL=   4.25 TWAP=   3.19  ########
#   t=49: RL=   3.47 TWAP=   3.19  ######
#   t=50: RL=   3.98 TWAP=   3.19  #######
#   t=51: RL=   3.41 TWAP=   3.19  ######
#   t=52: RL=   4.82 TWAP=   3.19  #########
#   t=53: RL=   4.07 TWAP=   3.19  #######
#   t=54: RL=   2.79 TWAP=   3.19  #####
#   t=55: RL=   2.65 TWAP=   3.19  #####
#   t=56: RL=   1.90 TWAP=   3.19  ###
#   t=57: RL=   1.19 TWAP=   3.19  ##
#   t=58: RL=   0.41 TWAP=   3.19
#   t=59: RL=   0.58 TWAP=   3.19  #
#
# Top 5 seconds by average position:
#   Second 52: 4.8221 (9.5%)
#   Second 45: 4.7915 (9.4%)
#   Second 44: 4.6484 (9.1%)
#   Second 48: 4.2500 (8.3%)
#   Second 46: 4.1376 (8.1%)

# %% [markdown]
# ## Generate Test Positions
#
# Run the agent on test data and save positions in the submission format.

# %%
# Generate positions for validation instruments (demo — replace with test data when available)
print("Generating positions for validation instruments...")

times = Y_raw["time_in_hour"].sort_values().unique()

test_positions_df = pd.DataFrame()
env = TradeExecutionEnv(val_instruments, volume_to_fill, K_SECONDS)

for i, inst in enumerate(val_instruments):
    obs, _ = env.reset(options={"instrument_idx": i})
    positions = np.zeros(60)
    for step in range(K_SECONDS):
        action, _ = model.predict(obs, deterministic=True)
        pos = env.action_multipliers[int(action)] * env.twap_rate
        max_rem = volume_to_fill - env.volume_allocated
        pos = min(pos, max(0.0, max_rem))
        if step == K_SECONDS - 1:
            pos = max(0.0, max_rem)

        abs_t = env.start_second + step
        positions[abs_t] = pos
        obs, _, done, _, _ = env.step(int(action))
        if done:
            break

    df = pd.DataFrame({
        'anonymized_id': inst['id'],
        'time_in_hour': times,
        'position': positions,
    })
    test_positions_df = pd.concat([test_positions_df, df], ignore_index=True)

base_path = Path(f"positions/{data_asset}")
base_path.mkdir(parents=True, exist_ok=True)
target = base_path / "rl_agent.parquet"
test_positions_df.to_parquet(target, index=False, engine='pyarrow')
print(f"Saved {len(test_positions_df)} rows to {target}")
# Out:
# Generating positions for validation instruments...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Saved 4680 rows to positions/LTCUSDT/rl_agent.parquet
