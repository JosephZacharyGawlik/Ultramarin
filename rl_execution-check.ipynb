# %% [markdown]
# # RL for Optimal Trade Execution
#
# A PPO agent that makes per-second execution decisions based on the current order book state.
# Instead of predicting 60 seconds ahead, the agent reacts to what it sees right now.

# %%
import os, sys, subprocess

# Colab setup
if os.path.exists("/content"):
    # Always ensure we're in the right directory
    repo_dir = "/content/Ultramarin"

    # Clone repo if needed (for simulate_walk_the_book.py)
    if not os.path.isdir(os.path.join(repo_dir, "utils")):
        subprocess.run(["git", "clone", "-q", "-b", "potentially-improve-model",
                        "https://github.com/JosephZacharyGawlik/Ultramarin.git"],
                       cwd="/content")

    os.chdir(repo_dir)
    if repo_dir not in sys.path:
        sys.path.insert(0, repo_dir)

    # Mount Drive and copy data if needed
    dst = os.path.join(repo_dir, "data")
    if not os.path.isdir(dst) or not any(
        d for d in os.listdir(dst) if os.path.isdir(os.path.join(dst, d))
    ):
        from google.colab import drive
        drive.mount('/content/drive')
        src = "/content/drive/MyDrive/data"
        os.makedirs(dst, exist_ok=True)
        subprocess.run(["cp", "-r", f"{src}/.", dst], capture_output=True, text=True)
        print("Data copied.")
    else:
        print(f"Data already present at {dst}")

subprocess.run([sys.executable, "-m", "pip", "install", "-q",
                "gymnasium", "stable-baselines3"], capture_output=True)
print("Setup complete.")
# Out:
# Data already present at /content/Ultramarin/data
# Setup complete.

# %%
import numpy as np
import pandas as pd
import math
import warnings
import random
from pathlib import Path

import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO

from data.simulate_walk_the_book import simulate_walk_the_book

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# === Change this to switch currencies ===
data_asset = "BTCUSDT"

KNOWN_VOLUMES = {
    "BTCUSDT": 4.0, "ETHUSDT": 55.0, "LTCUSDT": 51.0,
    "SOLUSDT": 315.0, "ADAUSDT": 10436.0, "DOGEUSDT": 60349.0, "XRPUSDT": 13736.0,
}
OPTIMAL_K = {
    "BTCUSDT": 14, "ETHUSDT": 26, "LTCUSDT": 16,
    "SOLUSDT": 17, "ADAUSDT": 7, "DOGEUSDT": 20, "XRPUSDT": 20,
}

volume_to_fill = KNOWN_VOLUMES[data_asset]
K_SECONDS = OPTIMAL_K[data_asset]

root = Path("data")
Y_path = root / data_asset / "y_train.parquet"

print(f"Currency: {data_asset}")
print(f"Volume to fill: {volume_to_fill}")
print(f"TWAP-K baseline: K={K_SECONDS}")
# Out:
# Currency: BTCUSDT
# Volume to fill: 4.0
# TWAP-K baseline: K=14

# %% [markdown]
# ## Data Loading
#
# Load Y data (the 60-second execution window), split into train/val using the same
# chrono split as mhf-final (sort IDs, 80/20 split), and pre-extract LOB arrays per instrument.

# %%
ASK_PRICE_COLS = [f'ask_price_{i}' for i in range(1, 6)]
ASK_VOL_COLS = [f'ask_vol_{i}' for i in range(1, 6)]
BID_PRICE_COLS = [f'bid_price_{i}' for i in range(1, 6)]
BID_VOL_COLS = [f'bid_vol_{i}' for i in range(1, 6)]

Y_raw = pd.read_parquet(Y_path).sort_values(["anonymized_id", "time_in_hour"])

# Clean prices and volumes the same way as mhf-final:
# 1. Forward-fill then backfill prices (handles NaN at start AND middle)
# 2. Zero-fill volumes
price_cols = ASK_PRICE_COLS + BID_PRICE_COLS
vol_cols = ASK_VOL_COLS + BID_VOL_COLS
Y_raw[price_cols] = Y_raw.groupby("anonymized_id")[price_cols].transform(
    lambda s: s.ffill().bfill()
)
Y_raw[vol_cols] = Y_raw[vol_cols].fillna(0.0)

# Get valid instrument IDs (exactly 60 rows)
id_counts = Y_raw.groupby("anonymized_id").size()
valid_ids = sorted(id_counts[id_counts == 60].index.tolist())

# Chrono split: same logic as train_val() — sort IDs, take last 20% as val
split_idx = int(len(valid_ids) * 0.8)
train_ids = valid_ids[:split_idx]
val_ids = valid_ids[split_idx:]

print(f"Valid instruments: {len(valid_ids)}")
print(f"Train: {len(train_ids)}, Val: {len(val_ids)}")


def extract_instruments(ids, df):
    """Pre-extract LOB arrays for each instrument."""
    instruments = []
    skipped = 0
    for aid in ids:
        df_inst = df[df["anonymized_id"] == aid].sort_values("time_in_hour")
        if len(df_inst) != 60:
            continue

        ask_prices = df_inst[ASK_PRICE_COLS].to_numpy(dtype=np.float64)
        bid_prices = df_inst[BID_PRICE_COLS].to_numpy(dtype=np.float64)
        ask_vols = df_inst[ASK_VOL_COLS].to_numpy(dtype=np.float64)
        bid_vols = df_inst[BID_VOL_COLS].to_numpy(dtype=np.float64)

        # Skip if level-1 prices are still NaN (entire column was NaN — no data at all)
        if np.isnan(ask_prices[:, 0]).any() or np.isnan(bid_prices[:, 0]).any():
            skipped += 1
            continue

        close_vals = df_inst["close"].dropna()
        if len(close_vals) == 0:
            skipped += 1
            continue

        instruments.append({
            "id": aid,
            "ask_prices": ask_prices,
            "ask_vols": ask_vols,
            "bid_prices": bid_prices,
            "bid_vols": bid_vols,
            "close": close_vals.iloc[-1],
        })
    if skipped > 0:
        print(f"  Skipped {skipped} instruments (all-NaN prices or missing close)")
    return instruments


train_instruments = extract_instruments(train_ids, Y_raw)
val_instruments = extract_instruments(val_ids, Y_raw)

print(f"Train instruments loaded: {len(train_instruments)}")
print(f"Val instruments loaded: {len(val_instruments)}")
# Out:
# Valid instruments: 705
# Train: 564, Val: 141
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Train instruments loaded: 564
# Val instruments loaded: 141
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## Gymnasium Environment
#
# Each episode = one instrument's last K-second execution window (same window as TWAP-K and Oracle).
# State: 12 features (remaining vol/time, spread, depth, imbalance, momentum, etc.)
# Action: 6 discrete choices — multiples of the TWAP-K rate
#
# **Key design: agent only trades in the last K seconds.**
# This matches the Oracle's optimization window and TWAP-K's execution window.
# Executing earlier hurts BPS because prices drift from the close price.
#
# **Reward (differential mark-to-market vs TWAP-K):**
# At each step, compare agent's cost-to-complete vs TWAP-K's cost-to-complete.
# Reward = change in advantage. Positive reward = agent is doing better than TWAP-K.

# %%
class TradeExecutionEnv(gym.Env):
    """
    RL environment for optimal trade execution in the last K seconds.

    Instead of trading across all 60 seconds (where price drift hurts BPS),
    the agent only trades in the last K seconds — the same window as TWAP-K
    and the Oracle optimizer. This makes the comparison fair and reduces noise.

    Reward: Differential mark-to-market advantage over TWAP-K.
    Action space: 10 discrete actions from 0x to 3x TWAP-K rate.
    """

    REWARD_SCALE = 10000  # puts rewards in ~bps units

    def __init__(self, instruments, volume_to_fill, K_seconds):
        super().__init__()
        self.instruments = instruments
        self.volume_to_fill = volume_to_fill
        self.K = K_seconds
        self.start_second = 60 - K_seconds
        self.twap_rate = volume_to_fill / K_seconds

        self.action_space = spaces.Discrete(10)
        self.action_multipliers = np.array([
            0.0, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 2.0, 2.5, 3.0
        ])

        self.observation_space = spaces.Box(
            low=-10.0, high=10.0, shape=(12,), dtype=np.float32
        )

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        if options and "instrument_idx" in options:
            idx = options["instrument_idx"]
        else:
            idx = self.np_random.integers(len(self.instruments))
        self.inst = self.instruments[idx]

        self.t = 0
        self.volume_executed = 0.0
        self.value_executed = 0.0
        self.volume_allocated = 0.0
        self.remaining_carry = 0.0
        self.prev_advantage = 0.0

        self._precompute_twap()

        abs_t = self.start_second
        self.arrival_mid = (
            self.inst["ask_prices"][abs_t, 0] + self.inst["bid_prices"][abs_t, 0]
        ) / 2

        return self._get_obs(), {}

    def _precompute_twap(self):
        """Run TWAP-K through walk-the-book for the last K seconds."""
        self.twap_cost_per_step = np.zeros(self.K)
        self.twap_vol_per_step = np.zeros(self.K)
        carry = 0.0
        for step in range(self.K):
            abs_t = self.start_second + step
            to_fill = self.twap_rate + carry
            carry = 0.0
            filled = 0.0
            cost = 0.0
            remaining = to_fill
            for level in range(5):
                price = self.inst["ask_prices"][abs_t, level]
                avail = self.inst["ask_vols"][abs_t, level]
                if math.isnan(price) or math.isnan(avail):
                    continue
                take = min(remaining, avail)
                cost += take * price
                filled += take
                remaining -= take
                if remaining <= 1e-12:
                    break
            carry = remaining
            self.twap_cost_per_step[step] = cost
            self.twap_vol_per_step[step] = filled
        self.twap_cum_cost = np.cumsum(self.twap_cost_per_step)
        self.twap_cum_vol = np.cumsum(self.twap_vol_per_step)

    def _get_obs(self):
        if self.t >= self.K:
            return np.zeros(12, dtype=np.float32)

        abs_t = self.start_second + self.t
        ask_p = self.inst["ask_prices"][abs_t]
        ask_v = self.inst["ask_vols"][abs_t]
        bid_p = self.inst["bid_prices"][abs_t]
        bid_v = self.inst["bid_vols"][abs_t]
        mid = (ask_p[0] + bid_p[0]) / 2

        remaining_vol = max(0, self.volume_to_fill - self.volume_allocated)
        remaining_vol_frac = remaining_vol / (self.volume_to_fill + 1e-8)
        remaining_time_frac = (self.K - self.t) / self.K
        spread = (ask_p[0] - bid_p[0]) / (mid + 1e-8)
        mid_return = (mid - self.arrival_mid) / (self.arrival_mid + 1e-8)

        vol_imb_1 = (bid_v[0] - ask_v[0]) / (bid_v[0] + ask_v[0] + 1e-8)
        vol_imb_total = (bid_v.sum() - ask_v.sum()) / (bid_v.sum() + ask_v.sum() + 1e-8)
        ask_depth = ask_v.sum() / (self.volume_to_fill + 1e-8)
        bid_depth = bid_v.sum() / (self.volume_to_fill + 1e-8)

        cum_is = 0.0
        if self.volume_executed > 0:
            avg_price = self.value_executed / self.volume_executed
            cum_is = (avg_price - self.arrival_mid) / (self.arrival_mid + 1e-8)

        if abs_t >= 5:
            mid_prev = (self.inst["ask_prices"][abs_t-5, 0] + self.inst["bid_prices"][abs_t-5, 0]) / 2
            momentum = (mid - mid_prev) / (self.arrival_mid + 1e-8)
            prev_spread = (self.inst["ask_prices"][abs_t-5, 0] - self.inst["bid_prices"][abs_t-5, 0]) / (mid_prev + 1e-8)
            spread_change = spread - prev_spread
        else:
            momentum = 0.0
            spread_change = 0.0

        carry_frac = self.remaining_carry / (self.volume_to_fill + 1e-8)

        obs = np.array([
            remaining_vol_frac,
            remaining_time_frac,
            spread,
            mid_return,
            vol_imb_1,
            vol_imb_total,
            ask_depth,
            bid_depth,
            cum_is,
            momentum,
            spread_change,
            carry_frac,
        ], dtype=np.float32)

        obs = np.nan_to_num(obs, nan=0.0, posinf=10.0, neginf=-10.0)
        obs = np.clip(obs, -10.0, 10.0)
        return obs

    def step(self, action):
        position = self.action_multipliers[action] * self.twap_rate

        max_remaining = self.volume_to_fill - self.volume_allocated
        position = min(position, max(0.0, max_remaining))

        if self.t == self.K - 1:
            position = max(0.0, max_remaining)

        self.volume_allocated += position

        abs_t = self.start_second + self.t
        to_fill = position + self.remaining_carry
        self.remaining_carry = 0.0
        step_volume = 0.0
        step_cost = 0.0

        if to_fill > 1e-12:
            remaining = to_fill
            for level in range(5):
                price = self.inst["ask_prices"][abs_t, level]
                avail = self.inst["ask_vols"][abs_t, level]
                if math.isnan(price) or math.isnan(avail):
                    continue
                take = min(remaining, avail)
                step_cost += take * price
                step_volume += take
                remaining -= take
                if remaining <= 1e-12:
                    break
            self.remaining_carry = remaining

        self.volume_executed += step_volume
        self.value_executed += step_cost

        # === REWARD: Differential mark-to-market advantage over TWAP-K ===
        mid_t = (self.inst["ask_prices"][abs_t, 0] + self.inst["bid_prices"][abs_t, 0]) / 2
        if math.isnan(mid_t):
            mid_t = self.arrival_mid

        agent_remaining = self.volume_to_fill - self.volume_executed
        agent_total_cost = self.value_executed + agent_remaining * mid_t

        twap_remaining = self.volume_to_fill - self.twap_cum_vol[self.t]
        twap_total_cost = self.twap_cum_cost[self.t] + twap_remaining * mid_t

        normalizer = self.arrival_mid * self.volume_to_fill
        advantage = (twap_total_cost - agent_total_cost) / normalizer

        reward = (advantage - self.prev_advantage) * self.REWARD_SCALE
        self.prev_advantage = advantage

        reward = max(-100.0, min(100.0, reward))

        self.t += 1
        done = self.t >= self.K
        info = {}

        if done:
            fill_ratio = self.volume_executed / (self.volume_to_fill + 1e-8)
            if fill_ratio < 0.99:
                reward -= (1.0 - fill_ratio) * 100.0

            if self.volume_executed > 0:
                avg_price = self.value_executed / self.volume_executed
                close = self.inst["close"]
                bps = abs(avg_price - close) / close * 10000
                vol_penalty = min(100.0, self.volume_to_fill / self.volume_executed)
                info["bps"] = bps * vol_penalty
                info["fill_ratio"] = fill_ratio
            else:
                info["bps"] = 10000.0
                info["fill_ratio"] = 0.0

        obs = self._get_obs()
        return obs, reward, done, False, info


# === Sanity checks ===
test_env = TradeExecutionEnv(train_instruments, volume_to_fill, K_SECONDS)

obs, _ = test_env.reset()
twap_reward = 0
for _ in range(K_SECONDS):
    obs, reward, done, _, info = test_env.step(4)  # action 4 = 1.0x
    twap_reward += reward
    if done:
        break
print(f"TWAP policy (action=4, 1.0x): BPS={info.get('bps', 'N/A'):.4f}, "
      f"Fill={info.get('fill_ratio', 0):.2%}, Reward={twap_reward:.4f}")

obs, _ = test_env.reset()
skip_reward = 0
for _ in range(K_SECONDS):
    obs, reward, done, _, info = test_env.step(0)  # action 0 = 0.0x
    skip_reward += reward
    if done:
        break
print(f"Skip policy (action=0, 0.0x):  BPS={info.get('bps', 'N/A'):.4f}, "
      f"Fill={info.get('fill_ratio', 0):.2%}, Reward={skip_reward:.4f}")

obs, _ = test_env.reset()
fast_reward = 0
for _ in range(K_SECONDS):
    obs, reward, done, _, info = test_env.step(9)  # action 9 = 3.0x
    fast_reward += reward
    if done:
        break
print(f"Fast policy (action=9, 3.0x):  BPS={info.get('bps', 'N/A'):.4f}, "
      f"Fill={info.get('fill_ratio', 0):.2%}, Reward={fast_reward:.4f}")

obs, _ = test_env.reset()
rand_reward = 0
for _ in range(K_SECONDS):
    obs, reward, done, _, info = test_env.step(test_env.action_space.sample())
    rand_reward += reward
    if done:
        break
print(f"Random policy:                 BPS={info.get('bps', 'N/A'):.4f}, "
      f"Fill={info.get('fill_ratio', 0):.2%}, Reward={rand_reward:.4f}")

nan_count = 0
for _ in range(20):
    obs, _ = test_env.reset()
    for _ in range(K_SECONDS):
        if np.isnan(obs).any():
            nan_count += 1
        obs, _, done, _, _ = test_env.step(test_env.action_space.sample())
        if done:
            break
print(f"\nNaN check: {nan_count} NaN observations in 20 episodes (should be 0)")
print(f"Episode length: {K_SECONDS} steps | Actions: {len(test_env.action_multipliers)} "
      f"({', '.join(f'{m}x' for m in test_env.action_multipliers)})")
# Out:
# TWAP policy (action=4, 1.0x): BPS=0.8176, Fill=100.00%, Reward=0.0000
# Skip policy (action=0, 0.0x):  BPS=17.2224, Fill=14.98%, Reward=-84.0473
# Fast policy (action=9, 3.0x):  BPS=2.5609, Fill=100.00%, Reward=-0.4109
# Random policy:                 BPS=0.0848, Fill=100.00%, Reward=-0.0839
#
# NaN check: 0 NaN observations in 20 episodes (should be 0)
# Episode length: 14 steps | Actions: 10 (0.0x, 0.25x, 0.5x, 0.75x, 1.0x, 1.25x, 1.5x, 2.0x, 2.5x, 3.0x)

# %% [markdown]
# ## Training
#
# PPO (Proximal Policy Optimization) with a small MLP policy (2 hidden layers, 64 neurons each).
# PPO uses trajectory rollouts rather than replay buffers, making it better suited for
# environments with small per-step reward signals. RL-Exec (BTC-USD execution) used PPO
# for this exact reason.

# %%
train_env = TradeExecutionEnv(train_instruments, volume_to_fill, K_SECONDS)

# Linear LR decay: 3e-4 → 0 over training
def linear_schedule(progress_remaining: float) -> float:
    return progress_remaining * 3e-4

model = PPO(
    "MlpPolicy",
    train_env,
    learning_rate=linear_schedule,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.01,
    vf_coef=0.5,
    max_grad_norm=0.5,
    policy_kwargs={"net_arch": [64, 64]},
    verbose=1,
    seed=SEED,
)

TOTAL_TIMESTEPS = 1_000_000
print(f"Training for {TOTAL_TIMESTEPS} timesteps (~{TOTAL_TIMESTEPS // K_SECONDS} episodes)...")
print(f"LR schedule: 3e-4 → 0 (linear decay)")
model.learn(total_timesteps=TOTAL_TIMESTEPS)
print("Training complete.")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Training for 1000000 timesteps (~71428 episodes)...
# LR schedule: 3e-4 → 0 (linear decay)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 14       |
# |    ep_rew_mean     | -0.931   |
# | time/              |          |
# |    fps             | 453      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.398      |
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013733694 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | -0.00432    |
# |    learning_rate        | 0.000299    |
# |    loss                 | 7.8         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 6.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.231      |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012726472 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.000299    |
# |    loss                 | 0.155       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.591       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.233      |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 4           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012211156 |
# |    clip_fraction        | 0.0899      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.000298    |
# |    loss                 | 0.0151      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00823    |
# |    value_loss           | 0.372       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.412      |
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 5           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010227865 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.329       |
# |    learning_rate        | 0.000298    |
# |    loss                 | -0.0304     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00702    |
# |    value_loss           | 0.079       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.322      |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 6           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009407737 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.000297    |
# |    loss                 | 0.446       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00715    |
# |    value_loss           | 0.673       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.385      |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 7           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008608676 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 0.000296    |
# |    loss                 | 0.0202      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00648    |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.191      |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 8           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008806266 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.000296    |
# |    loss                 | -0.0353     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00716    |
# |    value_loss           | 0.593       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.278      |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 9           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009549741 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.000295    |
# |    loss                 | 0.00198     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00823    |
# |    value_loss           | 0.0658      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.261      |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 10          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008952631 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.000294    |
# |    loss                 | -0.00738    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0055     |
# |    value_loss           | 0.178       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.21       |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 11          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009595457 |
# |    clip_fraction        | 0.0718      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.192       |
# |    learning_rate        | 0.000294    |
# |    loss                 | 0.343       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00534    |
# |    value_loss           | 0.215       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.267       |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 12           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0113526555 |
# |    clip_fraction        | 0.104        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.18        |
# |    explained_variance   | 0.2          |
# |    learning_rate        | 0.000293     |
# |    loss                 | 0.025        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.009       |
# |    value_loss           | 0.604        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14         |
# |    ep_rew_mean          | -0.117     |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 13         |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01031306 |
# |    clip_fraction        | 0.0775     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.16      |
# |    explained_variance   | 0.116      |
# |    learning_rate        | 0.000293   |
# |    loss                 | 0.0444     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00803   |
# |    value_loss           | 0.42       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.426      |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 14          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009050334 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.000292    |
# |    loss                 | -0.00965    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00871    |
# |    value_loss           | 0.0588      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.571       |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 15           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0058198976 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 0.000291     |
# |    loss                 | 0.291        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00274     |
# |    value_loss           | 0.873        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.317       |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 16           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0065786988 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | 0.129        |
# |    learning_rate        | 0.000291     |
# |    loss                 | 0.438        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00561     |
# |    value_loss           | 2.61         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.5         |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 17           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0070064925 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 0.00029      |
# |    loss                 | 0.0992       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 4.07         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.52       |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 18          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011170136 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.00029     |
# |    loss                 | 0.13        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00957    |
# |    value_loss           | 1.92        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.157      |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 19          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011330393 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.000289    |
# |    loss                 | 0.0101      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00933    |
# |    value_loss           | 1.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.243      |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 20          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009580505 |
# |    clip_fraction        | 0.094       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | -0.209      |
# |    learning_rate        | 0.000288    |
# |    loss                 | -0.0117     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.097       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14         |
# |    ep_rew_mean          | -0.129     |
# | time/                   |            |
# |    fps                  | 388        |
# |    iterations           | 21         |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01096742 |
# |    clip_fraction        | 0.0967     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.99      |
# |    explained_variance   | 0.24       |
# |    learning_rate        | 0.000288   |
# |    loss                 | 0.00448    |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0092    |
# |    value_loss           | 0.0932     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.26       |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 22          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007881809 |
# |    clip_fraction        | 0.069       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.000287    |
# |    loss                 | -0.00514    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00707    |
# |    value_loss           | 0.0837      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.332      |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 23          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011162205 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.226       |
# |    learning_rate        | 0.000286    |
# |    loss                 | -0.0123     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 0.0733      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.283      |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 24          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007892683 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.0801      |
# |    learning_rate        | 0.000286    |
# |    loss                 | 1.76        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00806    |
# |    value_loss           | 0.615       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.239       |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 25           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0073332405 |
# |    clip_fraction        | 0.0834       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.000285     |
# |    loss                 | 0.0209       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00989     |
# |    value_loss           | 1.2          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.146      |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 26          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.007130023 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.26        |
# |    learning_rate        | 0.000285    |
# |    loss                 | 0.198       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00689    |
# |    value_loss           | 0.235       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.229       |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 27           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0071867635 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.244        |
# |    learning_rate        | 0.000284     |
# |    loss                 | 0.949        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00569     |
# |    value_loss           | 0.829        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14         |
# |    ep_rew_mean          | -0.12      |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 28         |
# |    time_elapsed         | 147        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01061142 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.81      |
# |    explained_variance   | -0.069     |
# |    learning_rate        | 0.000283   |
# |    loss                 | 0.217      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0114    |
# |    value_loss           | 0.175      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14         |
# |    ep_rew_mean          | -0.136     |
# | time/                   |            |
# |    fps                  | 388        |
# |    iterations           | 29         |
# |    time_elapsed         | 152        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.00894242 |
# |    clip_fraction        | 0.0819     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.77      |
# |    explained_variance   | 0.204      |
# |    learning_rate        | 0.000283   |
# |    loss                 | 0.00118    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.00995   |
# |    value_loss           | 0.091      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.274      |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 30          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.007543085 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.352       |
# |    learning_rate        | 0.000282    |
# |    loss                 | -0.0261     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00893    |
# |    value_loss           | 0.0391      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.273      |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 31          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010325247 |
# |    clip_fraction        | 0.0994      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.0993      |
# |    learning_rate        | 0.000282    |
# |    loss                 | 0.407       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00727    |
# |    value_loss           | 0.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.225      |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 32          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007960734 |
# |    clip_fraction        | 0.057       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.113       |
# |    learning_rate        | 0.000281    |
# |    loss                 | 0.666       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 1.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.182      |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 33          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008120051 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.00028     |
# |    loss                 | 0.77        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 0.486       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14         |
# |    ep_rew_mean          | -0.107     |
# | time/                   |            |
# |    fps                  | 387        |
# |    iterations           | 34         |
# |    time_elapsed         | 179        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.01112243 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.83      |
# |    explained_variance   | 0.183      |
# |    learning_rate        | 0.00028    |
# |    loss                 | 0.997      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00799   |
# |    value_loss           | 1.01       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.298      |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 35          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009536188 |
# |    clip_fraction        | 0.0862      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | -0.653      |
# |    learning_rate        | 0.000279    |
# |    loss                 | -0.0029     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0089     |
# |    value_loss           | 0.0597      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.133       |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 36           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0077841477 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.000278     |
# |    loss                 | 0.403        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00557     |
# |    value_loss           | 0.464        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.151      |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 37          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008997219 |
# |    clip_fraction        | 0.0731      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | -0.704      |
# |    learning_rate        | 0.000278    |
# |    loss                 | -0.00438    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00763    |
# |    value_loss           | 0.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.136      |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 38          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010378993 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.000277    |
# |    loss                 | 0.31        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0061     |
# |    value_loss           | 0.205       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.122      |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 39          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.010050938 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.000277    |
# |    loss                 | -0.00752    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.0455      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.341      |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 40          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007821374 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.000276    |
# |    loss                 | -0.0341     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00866    |
# |    value_loss           | 0.0417      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.277      |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 41          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.009347873 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.000275    |
# |    loss                 | 0.0577      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00648    |
# |    value_loss           | 0.529       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.173      |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 42          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.012649446 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.000275    |
# |    loss                 | 0.232       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00822    |
# |    value_loss           | 0.499       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.295      |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 43          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006563638 |
# |    clip_fraction        | 0.0615      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.000274    |
# |    loss                 | -0.0218     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00703    |
# |    value_loss           | 0.0846      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.108      |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 44          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009787558 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.000274    |
# |    loss                 | 0.0336      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 1.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.0694     |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 45          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.009203261 |
# |    clip_fraction        | 0.0858      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.000273    |
# |    loss                 | -0.02       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00783    |
# |    value_loss           | 0.144       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.168      |
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 46          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006809661 |
# |    clip_fraction        | 0.083       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | -0.277      |
# |    learning_rate        | 0.000272    |
# |    loss                 | -0.00704    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00776    |
# |    value_loss           | 0.0401      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.0905      |
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 47           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0077705663 |
# |    clip_fraction        | 0.084        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.64        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.000272     |
# |    loss                 | 0.139        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00749     |
# |    value_loss           | 0.166        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.15        |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 48           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0074523836 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.65        |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.000271     |
# |    loss                 | 0.00191      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00538     |
# |    value_loss           | 0.127        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.148      |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 49          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.006097806 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.000271    |
# |    loss                 | 0.0081      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 0.173       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.0992     |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 50          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007583836 |
# |    clip_fraction        | 0.0542      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.00027     |
# |    loss                 | 0.462       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00522    |
# |    value_loss           | 0.358       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.243      |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 51          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008354989 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | -0.00671    |
# |    learning_rate        | 0.000269    |
# |    loss                 | -0.0319     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00873    |
# |    value_loss           | 0.0429      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.0524     |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 52          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013502348 |
# |    clip_fraction        | 0.098       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 0.000269    |
# |    loss                 | 0.0227      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0074     |
# |    value_loss           | 0.338       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.33       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 53          |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.009291064 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.0393      |
# |    learning_rate        | 0.000268    |
# |    loss                 | 0.0239      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00743    |
# |    value_loss           | 0.113       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.524      |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 54          |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.010982627 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.000267    |
# |    loss                 | 6.5         |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00396    |
# |    value_loss           | 2.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | -0.0857     |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 55          |
# ...
# |    approx_kl            | 0.0018184473 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0.329        |
# |    learning_rate        | 1.06e-05     |
# |    loss                 | -0.0121      |
# |    n_updates            | 4710         |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 0.152        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14            |
# |    ep_rew_mean          | -0.136        |
# | time/                   |               |
# |    fps                  | 397           |
# |    iterations           | 473           |
# |    time_elapsed         | 2439          |
# |    total_timesteps      | 968704        |
# | train/                  |               |
# |    approx_kl            | 0.00085353485 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | -1.35         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.00373       |
# |    n_updates            | 4720          |
# |    policy_gradient_loss | -0.000874     |
# |    value_loss           | 0.0932        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14            |
# |    ep_rew_mean          | -0.041        |
# | time/                   |               |
# |    fps                  | 397           |
# |    iterations           | 474           |
# |    time_elapsed         | 2443          |
# |    total_timesteps      | 970752        |
# | train/                  |               |
# |    approx_kl            | 0.00038856344 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0.243         |
# |    learning_rate        | 9.39e-06      |
# |    loss                 | 0.429         |
# |    n_updates            | 4730          |
# |    policy_gradient_loss | -0.00041      |
# |    value_loss           | 0.288         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14            |
# |    ep_rew_mean          | -0.046        |
# | time/                   |               |
# |    fps                  | 397           |
# |    iterations           | 475           |
# |    time_elapsed         | 2449          |
# |    total_timesteps      | 972800        |
# | train/                  |               |
# |    approx_kl            | 0.00023559673 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0.357         |
# |    learning_rate        | 8.77e-06      |
# |    loss                 | 0.00674       |
# |    n_updates            | 4740          |
# |    policy_gradient_loss | -0.000716     |
# |    value_loss           | 1.16          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14            |
# |    ep_rew_mean          | -0.0465       |
# | time/                   |               |
# |    fps                  | 397           |
# |    iterations           | 476           |
# |    time_elapsed         | 2454          |
# |    total_timesteps      | 974848        |
# | train/                  |               |
# |    approx_kl            | 0.00035917695 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | 0.0945        |
# |    learning_rate        | 8.16e-06      |
# |    loss                 | 0.211         |
# |    n_updates            | 4750          |
# |    policy_gradient_loss | -0.000964     |
# |    value_loss           | 0.205         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14            |
# |    ep_rew_mean          | -0.186        |
# | time/                   |               |
# |    fps                  | 397           |
# |    iterations           | 477           |
# |    time_elapsed         | 2459          |
# |    total_timesteps      | 976896        |
# | train/                  |               |
# |    approx_kl            | 0.00021240438 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0.162         |
# |    learning_rate        | 7.55e-06      |
# |    loss                 | 0.0053        |
# |    n_updates            | 4760          |
# |    policy_gradient_loss | -0.000808     |
# |    value_loss           | 0.0643        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14            |
# |    ep_rew_mean          | -0.0617       |
# | time/                   |               |
# |    fps                  | 397           |
# |    iterations           | 478           |
# |    time_elapsed         | 2464          |
# |    total_timesteps      | 978944        |
# | train/                  |               |
# |    approx_kl            | 0.00030116178 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | 0.376         |
# |    learning_rate        | 6.93e-06      |
# |    loss                 | -0.00629      |
# |    n_updates            | 4770          |
# |    policy_gradient_loss | -0.000549     |
# |    value_loss           | 0.611         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.0517      |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 479          |
# |    time_elapsed         | 2469         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0005440325 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | -0.0207      |
# |    learning_rate        | 6.32e-06     |
# |    loss                 | -0.00189     |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.000692    |
# |    value_loss           | 0.0669       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.0297      |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 480          |
# |    time_elapsed         | 2475         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0006747806 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0.0935       |
# |    learning_rate        | 5.7e-06      |
# |    loss                 | 0.00446      |
# |    n_updates            | 4790         |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 0.0325       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14         |
# |    ep_rew_mean          | -0.0807    |
# | time/                   |            |
# |    fps                  | 397        |
# |    iterations           | 481        |
# |    time_elapsed         | 2480       |
# |    total_timesteps      | 985088     |
# | train/                  |            |
# |    approx_kl            | 8.2413e-05 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | -0.189     |
# |    learning_rate        | 5.09e-06   |
# |    loss                 | -0.00823   |
# |    n_updates            | 4800       |
# |    policy_gradient_loss | -0.000435  |
# |    value_loss           | 0.0735     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.0186      |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 482          |
# |    time_elapsed         | 2485         |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0002740768 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.623        |
# |    learning_rate        | 4.47e-06     |
# |    loss                 | 0.0191       |
# |    n_updates            | 4810         |
# |    policy_gradient_loss | -0.000622    |
# |    value_loss           | 0.122        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.0168      |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 483          |
# |    time_elapsed         | 2491         |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0002126995 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 3.86e-06     |
# |    loss                 | -0.0112      |
# |    n_updates            | 4820         |
# |    policy_gradient_loss | -0.000781    |
# |    value_loss           | 0.0303       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14            |
# |    ep_rew_mean          | -0.113        |
# | time/                   |               |
# |    fps                  | 397           |
# |    iterations           | 484           |
# |    time_elapsed         | 2496          |
# |    total_timesteps      | 991232        |
# | train/                  |               |
# |    approx_kl            | 0.00042967522 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.52         |
# |    explained_variance   | -0.192        |
# |    learning_rate        | 3.24e-06      |
# |    loss                 | -0.00963      |
# |    n_updates            | 4830          |
# |    policy_gradient_loss | -0.0011       |
# |    value_loss           | 0.0487        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.0289      |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 485          |
# |    time_elapsed         | 2501         |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0003094092 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.247        |
# |    learning_rate        | 2.63e-06     |
# |    loss                 | 0.164        |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 0.28         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.201       |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 486          |
# |    time_elapsed         | 2506         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 3.645316e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.599        |
# |    learning_rate        | 2.02e-06     |
# |    loss                 | 0.21         |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.000221    |
# |    value_loss           | 0.13         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14           |
# |    ep_rew_mean          | -0.363       |
# | time/                   |              |
# |    fps                  | 397          |
# |    iterations           | 487          |
# |    time_elapsed         | 2511         |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 8.822506e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0.322        |
# |    learning_rate        | 1.4e-06      |
# |    loss                 | -0.00424     |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.000127    |
# |    value_loss           | 0.656        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14            |
# |    ep_rew_mean          | -0.00472      |
# | time/                   |               |
# |    fps                  | 397           |
# |    iterations           | 488           |
# |    time_elapsed         | 2517          |
# |    total_timesteps      | 999424        |
# | train/                  |               |
# |    approx_kl            | 1.6052218e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0.326         |
# |    learning_rate        | 7.87e-07      |
# |    loss                 | 0.767         |
# |    n_updates            | 4870          |
# |    policy_gradient_loss | -6.41e-05     |
# |    value_loss           | 0.789         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14            |
# |    ep_rew_mean          | -0.0197       |
# | time/                   |               |
# |    fps                  | 397           |
# |    iterations           | 489           |
# |    time_elapsed         | 2521          |
# |    total_timesteps      | 1001472       |
# | train/                  |               |
# |    approx_kl            | 7.8236917e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.52         |
# |    explained_variance   | -0.235        |
# |    learning_rate        | 1.73e-07      |
# |    loss                 | 0.00129       |
# |    n_updates            | 4880          |
# |    policy_gradient_loss | -4.38e-05     |
# |    value_loss           | 0.0514        |
# -------------------------------------------
# Training complete.

# %% [markdown]
# ## Evaluation
#
# Run the trained agent on validation instruments and compare BPS against TWAP-K.
# Uses `simulate_walk_the_book()` for final BPS — same function as all other strategies.

# %%
def evaluate(model, instruments, volume_to_fill, K_seconds):
    """Evaluate RL agent vs multiple TWAP baselines on a set of instruments."""
    env = TradeExecutionEnv(instruments, volume_to_fill, K_seconds)
    rl_bps_list = []
    twap_k_bps_list = []
    twap_14_bps_list = []
    twap_60_bps_list = []
    rl_positions_all = []

    for i in range(len(instruments)):
        inst = instruments[i]
        ask_prices = inst["ask_prices"]
        ask_vols = inst["ask_vols"]
        bid_prices = inst["bid_prices"]
        bid_vols = inst["bid_vols"]
        close_price = inst["close"]

        # --- RL Agent ---
        obs, _ = env.reset(options={"instrument_idx": i})
        rl_positions = np.zeros(60)
        for step in range(K_seconds):
            action, _ = model.predict(obs, deterministic=True)

            position = env.action_multipliers[int(action)] * env.twap_rate
            max_remaining = volume_to_fill - env.volume_allocated
            position = min(position, max(0.0, max_remaining))
            if step == K_seconds - 1:
                position = max(0.0, max_remaining)

            abs_t = env.start_second + step
            rl_positions[abs_t] = position

            obs, _, done, _, _ = env.step(int(action))
            if done:
                break

        rl_positions_all.append(rl_positions)

        def compute_bps(positions):
            vol, avg = simulate_walk_the_book(
                positions, ask_prices, ask_vols, bid_prices, bid_vols
            )
            if vol > 0 and not np.isnan(avg):
                ie = abs(avg - close_price) / close_price * 10000
                vp = min(100.0, volume_to_fill / vol)
                return ie * vp
            return None

        # --- RL BPS ---
        bps = compute_bps(rl_positions)
        if bps is not None:
            rl_bps_list.append(bps)

        # --- TWAP-K ---
        twap_k_pos = np.zeros(60)
        twap_k_pos[-K_seconds:] = volume_to_fill / K_seconds
        bps = compute_bps(twap_k_pos)
        if bps is not None:
            twap_k_bps_list.append(bps)

        # --- TWAP-14 ---
        twap_14_pos = np.zeros(60)
        twap_14_pos[-14:] = volume_to_fill / 14
        bps = compute_bps(twap_14_pos)
        if bps is not None:
            twap_14_bps_list.append(bps)

        # --- TWAP-60 ---
        twap_60_pos = np.full(60, volume_to_fill / 60)
        bps = compute_bps(twap_60_pos)
        if bps is not None:
            twap_60_bps_list.append(bps)

    return (np.array(rl_bps_list), np.array(twap_k_bps_list),
            np.array(twap_14_bps_list), np.array(twap_60_bps_list),
            rl_positions_all)


rl_bps, twap_k_bps, twap_14_bps, twap_60_bps, rl_positions_all = evaluate(
    model, val_instruments, volume_to_fill, K_SECONDS
)

print(f"\n{'='*60}")
print(f"RESULTS: {data_asset} (volume={volume_to_fill})")
print(f"{'='*60}")
print(f"{'Strategy':<20} {'Mean BPS':>10} {'Median BPS':>12}")
print(f"{'-'*60}")
print(f"{'RL Agent':<20} {rl_bps.mean():>10.4f} {np.median(rl_bps):>12.4f}")
print(f"{'TWAP-' + str(K_SECONDS) + 's':<20} {twap_k_bps.mean():>10.4f} {np.median(twap_k_bps):>12.4f}")
print(f"{'TWAP-14s':<20} {twap_14_bps.mean():>10.4f} {np.median(twap_14_bps):>12.4f}")
print(f"{'TWAP-60s':<20} {twap_60_bps.mean():>10.4f} {np.median(twap_60_bps):>12.4f}")
print(f"{'-'*60}")

# Compare RL against each baseline
for name, baseline in [("TWAP-" + str(K_SECONDS), twap_k_bps),
                        ("TWAP-14", twap_14_bps),
                        ("TWAP-60", twap_60_bps)]:
    diff = baseline.mean() - rl_bps.mean()
    wins = (rl_bps < baseline).sum()
    pct = (rl_bps < baseline).mean() * 100
    label = "RL wins" if diff > 0 else "TWAP wins"
    print(f"RL vs {name:<8}: {diff:+.4f} bps ({label}), "
          f"RL wins {wins}/{len(rl_bps)} ({pct:.1f}%)")

print(f"{'='*60}")
print(f"Instruments evaluated: {len(rl_bps)}")
print(f"\nSubmission comparison (TWAP-14): 5.0781 BPS")
# Out:
# ============================================================
# RESULTS: BTCUSDT (volume=4.0)
# ============================================================
# Strategy               Mean BPS   Median BPS
# ------------------------------------------------------------
# RL Agent                 1.4437       1.2261
# TWAP-14s                 1.3232       1.1836
# TWAP-14s                 1.3232       1.1836
# TWAP-60s                 1.7176       1.2783
# ------------------------------------------------------------
# RL vs TWAP-14 : -0.1205 bps (TWAP wins), RL wins 46/141 (32.6%)
# RL vs TWAP-14 : -0.1205 bps (TWAP wins), RL wins 46/141 (32.6%)
# RL vs TWAP-60 : +0.2738 bps (RL wins), RL wins 78/141 (55.3%)
# ============================================================
# Instruments evaluated: 141
#
# Submission comparison (TWAP-14): 5.0781 BPS

# %% [markdown]
# ## Policy Analysis
#
# Examine what the agent learned: average position profile across instruments,
# compared to TWAP allocation.

# %%
# Average position profile
positions_array = np.array(rl_positions_all)  # [num_instruments, 60]
avg_positions = positions_array.mean(axis=0)

# TWAP-K profile for comparison
twap_profile = np.zeros(60)
twap_profile[-K_SECONDS:] = volume_to_fill / K_SECONDS

print("RL Agent — Average position profile (last K seconds):")
print(f"  Volume in last {K_SECONDS}s:   {avg_positions[-K_SECONDS:].sum():.4f} ({avg_positions[-K_SECONDS:].sum()/volume_to_fill*100:.1f}%)")
print(f"  Volume in last 5s:    {avg_positions[-5:].sum():.4f} ({avg_positions[-5:].sum()/volume_to_fill*100:.1f}%)")
print(f"  Volume at last sec:   {avg_positions[59]:.4f} ({avg_positions[59]/volume_to_fill*100:.1f}%)")
print()
print(f"Per-second breakdown (last {K_SECONDS} seconds):")
start = 60 - K_SECONDS
for s in range(start, 60):
    rl_avg = avg_positions[s]
    twap_avg = twap_profile[s]
    bar = '#' * int(rl_avg / volume_to_fill * 100)
    print(f"  t={s:2d}: RL={rl_avg:7.2f} TWAP={twap_avg:7.2f}  {bar}")
print()
print(f"Top 5 seconds by average position:")
top5 = np.argsort(avg_positions)[-5:][::-1]
for s in top5:
    print(f"  Second {s}: {avg_positions[s]:.4f} ({avg_positions[s]/volume_to_fill*100:.1f}%)")
# Out:
# RL Agent — Average position profile (last K seconds):
#   Volume in last 14s:   4.0000 (100.0%)
#   Volume in last 5s:    0.7761 (19.4%)
#   Volume at last sec:   0.0025 (0.1%)
#
# Per-second breakdown (last 14 seconds):
#   t=46: RL=   0.40 TWAP=   0.29  ##########
#   t=47: RL=   0.41 TWAP=   0.29  ##########
#   t=48: RL=   0.39 TWAP=   0.29  #########
#   t=49: RL=   0.39 TWAP=   0.29  #########
#   t=50: RL=   0.36 TWAP=   0.29  ########
#   t=51: RL=   0.36 TWAP=   0.29  #########
#   t=52: RL=   0.31 TWAP=   0.29  #######
#   t=53: RL=   0.30 TWAP=   0.29  #######
#   t=54: RL=   0.30 TWAP=   0.29  #######
#   t=55: RL=   0.29 TWAP=   0.29  #######
#   t=56: RL=   0.27 TWAP=   0.29  ######
#   t=57: RL=   0.17 TWAP=   0.29  ####
#   t=58: RL=   0.04 TWAP=   0.29  #
#   t=59: RL=   0.00 TWAP=   0.29
#
# Top 5 seconds by average position:
#   Second 47: 0.4093 (10.2%)
#   Second 46: 0.4037 (10.1%)
#   Second 48: 0.3875 (9.7%)
#   Second 49: 0.3855 (9.6%)
#   Second 51: 0.3612 (9.0%)

# %% [markdown]
# ## Generate Test Positions
#
# Run the agent on test data and save positions in the submission format.

# %%
# Generate positions for validation instruments (demo — replace with test data when available)
print("Generating positions for validation instruments...")

times = Y_raw["time_in_hour"].sort_values().unique()

test_positions_df = pd.DataFrame()
env = TradeExecutionEnv(val_instruments, volume_to_fill, K_SECONDS)

for i, inst in enumerate(val_instruments):
    obs, _ = env.reset(options={"instrument_idx": i})
    positions = np.zeros(60)
    for step in range(K_SECONDS):
        action, _ = model.predict(obs, deterministic=True)
        pos = env.action_multipliers[int(action)] * env.twap_rate
        max_rem = volume_to_fill - env.volume_allocated
        pos = min(pos, max(0.0, max_rem))
        if step == K_SECONDS - 1:
            pos = max(0.0, max_rem)

        abs_t = env.start_second + step
        positions[abs_t] = pos
        obs, _, done, _, _ = env.step(int(action))
        if done:
            break

    df = pd.DataFrame({
        'anonymized_id': inst['id'],
        'time_in_hour': times,
        'position': positions,
    })
    test_positions_df = pd.concat([test_positions_df, df], ignore_index=True)

base_path = Path(f"positions/{data_asset}")
base_path.mkdir(parents=True, exist_ok=True)
target = base_path / "rl_agent.parquet"
test_positions_df.to_parquet(target, index=False, engine='pyarrow')
print(f"Saved {len(test_positions_df)} rows to {target}")
# Out:
# Generating positions for validation instruments...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Saved 8460 rows to positions/BTCUSDT/rl_agent.parquet
